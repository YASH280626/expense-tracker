# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/Personal_Finance_Dataset.csv')

df.head()
# df.tail()
# print(df.columns)
# print(df.shape)
# print(df.shape[0])
# print(df.shape[1])
# Out:
#          Date                   Transaction Description      Category  \
# 0  2020-01-02                               Score each.  Food & Drink
# 1  2020-01-02                       Quality throughout.     Utilities
# 2  2020-01-04        Instead ahead despite measure ago.          Rent
# 3  2020-01-05  Information last everything thank serve.    Investment
# 4  2020-01-13              Future choice whatever from.  Food & Drink
#
#     Amount     Type
# 0  1485.69  Expense
# 1  1475.58  Expense
# 2  1185.08  Expense
# 3  2291.00   Income
# 4  1126.88  Expense

# %%
print(df.columns)
# Out:
# Index(['Date', 'Transaction Description', 'Category', 'Amount', 'Type'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                       0
# Transaction Description    0
# Category                   0
# Amount                     0
# Type                       0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Date                       False
# Transaction Description    False
# Category                   False
# Amount                     False
# Type                       False
# dtype: bool

# %%
df.isnull().axis = 1

# %%
df.isnull().axis = 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1500 non-null   object
#  1   Transaction Description  1500 non-null   object
#  2   Category                 1500 non-null   object
#  3   Amount                   1500 non-null   float64
#  4   Type                     1500 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 58.7+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1500 non-null   datetime64[ns]
#  1   Transaction Description  1500 non-null   object
#  2   Category                 1500 non-null   object
#  3   Amount                   1500 non-null   float64
#  4   Type                     1500 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 58.7+ KB

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df['Transaction Description'].unique())
# Out:
# ['Score each.' 'Quality throughout.' 'Instead ahead despite measure ago.'
#  ... 'No couple debate must.' 'Discussion black follow.'
#  'Pressure activity defense detail.']

# %%
print(df['Type'].unique())
# Out:
# ['Expense' 'Income']

# %%
print(df['Category'].unique())
# Out:
# ['Food & Drink' 'Utilities' 'Rent' 'Investment' 'Shopping' 'Other'
#  'Entertainment' 'Health & Fitness' 'Salary' 'Travel']

# %%
print(df['Category'].value_counts())
# Out:
# Category
# Rent                165
# Travel              160
# Utilities           157
# Health & Fitness    152
# Shopping            150
# Food & Drink        149
# Salary              146
# Entertainment       143
# Investment          142
# Other               136
# Name: count, dtype: int64

# %%
print(df.groupby('Category')['Amount'].sum())
# Out:
# Category
# Entertainment       148165.47
# Food & Drink        159493.39
# Health & Fitness    145194.06
# Investment          363252.00
# Other               370835.00
# Rent                162075.39
# Salary              149053.55
# Shopping            146880.75
# Travel              169497.79
# Utilities           146833.97
# Name: Amount, dtype: float64

# %%
expense_df = df[df['Type'] == 'Expense']
expense_df['Type'].unique()
# Out:
# array(['Expense'], dtype=object)

# %%
expense_df.groupby('Category')['Amount'].sum().sort_values(ascending=False)
# Out:
# Category
# Travel              169497.79
# Rent                162075.39
# Food & Drink        159493.39
# Salary              149053.55
# Entertainment       148165.47
# Shopping            146880.75
# Utilities           146833.97
# Health & Fitness    145194.06
# Name: Amount, dtype: float64

# %%
expense_df.groupby('Category')['Type'].unique()
# Out:
# Category
# Entertainment       [Expense]
# Food & Drink        [Expense]
# Health & Fitness    [Expense]
# Rent                [Expense]
# Salary              [Expense]
# Shopping            [Expense]
# Travel              [Expense]
# Utilities           [Expense]
# Name: Type, dtype: object

# %%
df.groupby('Category')['Type'].unique()
# Out:
# Category
# Entertainment       [Expense]
# Food & Drink        [Expense]
# Health & Fitness    [Expense]
# Investment           [Income]
# Other                [Income]
# Rent                [Expense]
# Salary              [Expense]
# Shopping            [Expense]
# Travel              [Expense]
# Utilities           [Expense]
# Name: Type, dtype: object

# %%
salary_df = df[df['Category'] == 'Salary']
salary_df.head()
salary_df.tail()
# Out:
#            Date       Transaction Description Category   Amount     Type
# 1458 2024-11-13        Dinner rich decide do.   Salary  1950.21  Expense
# 1468 2024-11-19               Bit need allow.   Salary   606.22  Expense
# 1478 2024-11-25  Red republican father party.   Salary   383.70  Expense
# 1481 2024-11-30              Project at risk.   Salary  1456.94  Expense
# 1493 2024-12-21                 Up hear draw.   Salary   784.35  Expense

# %%
df.groupby(['Category', 'Type']).size()
# Out:
# Category          Type
# Entertainment     Expense    143
# Food & Drink      Expense    149
# Health & Fitness  Expense    152
# Investment        Income     142
# Other             Income     136
# Rent              Expense    165
# Salary            Expense    146
# Shopping          Expense    150
# Travel            Expense    160
# Utilities         Expense    157
# dtype: int64

# %% [markdown]
# How many income and expense transactions are there in the dataset

# %%
df['Type'].value_counts()
# Out:
# Type
# Expense    1222
# Income      278
# Name: count, dtype: int64

# %% [markdown]
# Inspecting Numericals Columns

# %%
df['Amount'].mean()
# Out:
# np.float64(1307.5209133333335)

# %%
df['Amount'].std()
# Out:
# np.float64(982.2833614507344)

# %%
df['Amount'].max()
# Out:
# np.float64(4996.0)

# %%
df['Amount'].min()
# Out:
# np.float64(14.37)

# %%
df['Amount'].count()
# Out:
# np.int64(1500)

# %%
df['Amount'].describe()
# Out:
# count    1500.000000
# mean     1307.520913
# std       982.283361
# min        14.370000
# 25%       629.340000
# 50%      1156.285000
# 75%      1712.932500
# max      4996.000000
# Name: Amount, dtype: float64

# %%
df.groupby('Type')['Amount'].mean()
# Out:
# Type
# Expense    1004.250712
# Income     2640.600719
# Name: Amount, dtype: float64

# %%
df.groupby('Type')['Amount'].describe()
# Out:
#           count         mean          std     min        25%       50%  \
# Type
# Expense  1222.0  1004.250712   571.536986   14.37   516.8025   992.855
# Income    278.0  2640.600719  1261.890414  500.00  1531.7500  2655.000
#
#                75%      max
# Type
# Expense  1484.9375  1999.82
# Income   3609.2500  4996.00

# %%
start_date = df['Date'].min()
print(start_date)
# Out:
# 2020-01-02 00:00:00

# %%
end_date = df['Date'].max()
print(end_date)
# Out:
# 2024-12-29 00:00:00

# %%
yearly_counts = df['Date'].dt.year.value_counts().sort_index()
print(yearly_counts)
# Out:
# Date
# 2020    290
# 2021    280
# 2022    303
# 2023    323
# 2024    304
# Name: count, dtype: int64

# %% [markdown]
# Total Transaction amount in each year

# %%
df.groupby([df['Date'].dt.year, 'Type'])['Amount'].sum()
# Out:
# Date  Type
# 2020  Expense    255772.86
#       Income     102266.00
# 2021  Expense    218644.46
#       Income     150398.00
# 2022  Expense    256776.35
#       Income     147726.00
# 2023  Expense    244498.24
#       Income     160598.00
# 2024  Expense    251502.46
#       Income     173099.00
# Name: Amount, dtype: float64

# %% [markdown]
# yearly_summary is now a dataframe

# %%
yearly_summary = df.groupby([df['Date'].dt.year, 'Type'])['Amount'].sum().unstack()
print(yearly_summary)
# Out:
# Type    Expense    Income
# Date
# 2020  255772.86  102266.0
# 2021  218644.46  150398.0
# 2022  256776.35  147726.0
# 2023  244498.24  160598.0
# 2024  251502.46  173099.0

# %%
yearly_summary['Savings'] = yearly_summary['Income'] - yearly_summary['Expense']
print(yearly_summary)
# Out:
# Type    Expense    Income    Savings
# Date
# 2020  255772.86  102266.0 -153506.86
# 2021  218644.46  150398.0  -68246.46
# 2022  256776.35  147726.0 -109050.35
# 2023  244498.24  160598.0  -83900.24
# 2024  251502.46  173099.0  -78403.46

# %% [markdown]
# creating a copy of df to change salary from expense to income

# %%
clean_df = df.copy()
clean_df.loc[clean_df['Category'] == 'Salary', 'Type'] = 'Income'
clean_df.head()
# Out:
#         Date                   Transaction Description      Category   Amount  \
# 0 2020-01-02                               Score each.  Food & Drink  1485.69
# 1 2020-01-02                       Quality throughout.     Utilities  1475.58
# 2 2020-01-04        Instead ahead despite measure ago.          Rent  1185.08
# 3 2020-01-05  Information last everything thank serve.    Investment  2291.00
# 4 2020-01-13              Future choice whatever from.  Food & Drink  1126.88
#
#       Type
# 0  Expense
# 1  Expense
# 2  Expense
# 3   Income
# 4  Expense

# %%
clean_df.groupby('Category')['Type'].unique()
# Out:
# Category
# Entertainment       [Expense]
# Food & Drink        [Expense]
# Health & Fitness    [Expense]
# Investment           [Income]
# Other                [Income]
# Rent                [Expense]
# Salary               [Income]
# Shopping            [Expense]
# Travel              [Expense]
# Utilities           [Expense]
# Name: Type, dtype: object

# %%
clean_yearly_summary = clean_df.groupby([clean_df['Date'].dt.year, 'Type'])['Amount'].sum().unstack()

# %%
clean_yearly_summary
# Out:
# Type    Expense     Income
# Date
# 2020  230296.73  127742.13
# 2021  194357.90  174684.56
# 2022  220761.52  183740.83
# 2023  217740.86  187355.38
# 2024  214983.81  209617.65

# %%
clean_yearly_summary['Savings'] = clean_yearly_summary['Income'] - clean_yearly_summary['Expense']
print(clean_yearly_summary)
# Out:
# Type    Expense     Income    Savings
# Date
# 2020  230296.73  127742.13 -102554.60
# 2021  194357.90  174684.56  -19673.34
# 2022  220761.52  183740.83  -37020.69
# 2023  217740.86  187355.38  -30385.48
# 2024  214983.81  209617.65   -5366.16

# %%
expensive_category = clean_df[clean_df['Type'] == 'Expense'].groupby('Category')['Amount'].sum().sort_values(ascending=False)
print(expensive_category)
# Out:
# Category
# Travel              169497.79
# Rent                162075.39
# Food & Drink        159493.39
# Entertainment       148165.47
# Shopping            146880.75
# Utilities           146833.97
# Health & Fitness    145194.06
# Name: Amount, dtype: float64

# %%
expensive_df = clean_df[clean_df['Type'] == 'Expense']
expensive_year = expensive_df[expensive_df['Type'] == 'Expense'].groupby([expensive_df['Date'].dt.year, 'Category'])['Amount'].sum()
print(expensive_year)
# Out:
# Date  Category
# 2020  Entertainment       31975.83
#       Food & Drink        31642.07
#       Health & Fitness    20426.95
#       Rent                38222.05
#       Shopping            29714.95
#       Travel              49156.49
#       Utilities           29158.39
# 2021  Entertainment       18784.58
#       Food & Drink        19268.06
#       Health & Fitness    33662.14
#       Rent                33428.82
#       Shopping            27685.78
#       Travel              26566.70
#       Utilities           34961.82
# 2022  Entertainment       35377.98
#       Food & Drink        33880.64
#       Health & Fitness    23286.14
#       Rent                37357.13
#       Shopping            38024.81
#       Travel              23166.28
#       Utilities           29668.54
# 2023  Entertainment       24225.53
#       Food & Drink        41607.68
#       Health & Fitness    37619.99
#       Rent                27722.98
#       Shopping            28301.05
# ...

# %%
expensive_by_year = expensive_year.unstack()
print(expensive_by_year)
# Out:
# Category  Entertainment  Food & Drink  Health & Fitness      Rent  Shopping  \
# Date
# 2020           31975.83      31642.07          20426.95  38222.05  29714.95
# 2021           18784.58      19268.06          33662.14  33428.82  27685.78
# 2022           35377.98      33880.64          23286.14  37357.13  38024.81
# 2023           24225.53      41607.68          37619.99  27722.98  28301.05
# 2024           37801.55      33094.94          30198.84  25344.41  23154.16
#
# Category    Travel  Utilities
# Date
# 2020      49156.49   29158.39
# 2021      26566.70   34961.82
# 2022      23166.28   29668.54
# 2023      30294.18   27969.45
# 2024      40314.14   25075.77

# %%
expensive_by_year.idxmax(axis = 1)
# Out:
# Date
# 2020          Travel
# 2021       Utilities
# 2022        Shopping
# 2023    Food & Drink
# 2024          Travel
# dtype: object

# %%
expensive_by_year.max(axis=1)
# Out:
# Date
# 2020    49156.49
# 2021    34961.82
# 2022    38024.81
# 2023    41607.68
# 2024    40314.14
# dtype: float64

# %%
index_top_year = expensive_by_year.index
final_frame = pd.DataFrame(index=index_top_year)
final_frame['Top Categories'] = expensive_by_year.idxmax(axis=1)
final_frame['Amount'] = expensive_by_year.max(axis=1)
print(final_frame)
# Out:
#      Top Categories    Amount
# Date
# 2020         Travel  49156.49
# 2021      Utilities  34961.82
# 2022       Shopping  38024.81
# 2023   Food & Drink  41607.68
# 2024         Travel  40314.14

# %%
import matplotlib.pyplot as plt

# %%
expensive_category.plot(kind ='bar')
plt.show()

# %%
expensive_category.plot(kind ='bar')
plt.title('Expense by Category')
plt.xlabel("Category")
plt.ylabel("Amount Spent")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
clean_yearly_summary.head()
# Out:
# Type    Expense     Income    Savings
# Date
# 2020  230296.73  127742.13 -102554.60
# 2021  194357.90  174684.56  -19673.34
# 2022  220761.52  183740.83  -37020.69
# 2023  217740.86  187355.38  -30385.48
# 2024  214983.81  209617.65   -5366.16

# %%
clean_yearly_summary[['Expense', 'Income']].plot(kind='bar', figsize=(8,5))
plt.title('Income Vs Expense by year')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.xticks(rotation=0)
plt.legend(title="Type")
plt.tight_layout()
plt.show()

# %%
clean_yearly_summary['Savings'].plot(kind='bar', figsize=(8,5))
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Saving by Year')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
expensive_category.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Expense Distribution')
plt.ylabel("")
plt.show()

# %%
expense_df = clean_df[clean_df['Type'] == 'Expense']
expense_df.head()
# Out:
#         Date             Transaction Description      Category   Amount  \
# 0 2020-01-02                         Score each.  Food & Drink  1485.69
# 1 2020-01-02                 Quality throughout.     Utilities  1475.58
# 2 2020-01-04  Instead ahead despite measure ago.          Rent  1185.08
# 4 2020-01-13        Future choice whatever from.  Food & Drink  1126.88
# 5 2020-01-14      Benefit suggest page southern.      Shopping   448.68
#
#       Type
# 0  Expense
# 1  Expense
# 2  Expense
# 4  Expense
# 5  Expense

# %%
expense_df['YearMonth'] = expense_df['Date'].dt.to_period('M')
# Out:
# /var/folders/0s/5twyp_vn65z96zc0yck0vr_h0000gn/T/ipykernel_34863/2033546452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expense_df['YearMonth'] = expense_df['Date'].dt.to_period('M')

# %%
expense_df.head()
# Out:
#         Date             Transaction Description      Category   Amount  \
# 0 2020-01-02                         Score each.  Food & Drink  1485.69
# 1 2020-01-02                 Quality throughout.     Utilities  1475.58
# 2 2020-01-04  Instead ahead despite measure ago.          Rent  1185.08
# 4 2020-01-13        Future choice whatever from.  Food & Drink  1126.88
# 5 2020-01-14      Benefit suggest page southern.      Shopping   448.68
#
#       Type YearMonth
# 0  Expense   2020-01
# 1  Expense   2020-01
# 2  Expense   2020-01
# 4  Expense   2020-01
# 5  Expense   2020-01

# %%
monthly_expense = expense_df.groupby('YearMonth')['Amount'].sum()

# %%
monthly_expense.plot(figsize=(12, 5))
plt.title('Monthly Expense Trend')
plt.xlabel('Month')
plt.ylabel('Expense')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
income_df = clean_df[clean_df['Type'] == 'Income']
income_df.head()
# Out:
#          Date                    Transaction Description    Category   Amount  \
# 3  2020-01-05   Information last everything thank serve.  Investment  2291.00
# 7  2020-01-19  Court attorney product significant world.       Other  3287.00
# 11 2020-01-26                   Range successful simply.      Salary  1077.09
# 20 2020-02-05              Seven medical blood personal.  Investment  1838.00
# 24 2020-02-08                   Staff within mouth call.       Other  3786.00
#
#       Type
# 3   Income
# 7   Income
# 11  Income
# 20  Income
# 24  Income

# %%
income_df['YearMonth'] = income_df['Date'].dt.to_period('M')
income_df.head()
# Out:
# /var/folders/0s/5twyp_vn65z96zc0yck0vr_h0000gn/T/ipykernel_34863/2790306677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_df['YearMonth'] = income_df['Date'].dt.to_period('M')
#          Date                    Transaction Description    Category   Amount  \
# 3  2020-01-05   Information last everything thank serve.  Investment  2291.00
# 7  2020-01-19  Court attorney product significant world.       Other  3287.00
# 11 2020-01-26                   Range successful simply.      Salary  1077.09
# 20 2020-02-05              Seven medical blood personal.  Investment  1838.00
# 24 2020-02-08                   Staff within mouth call.       Other  3786.00
#
#       Type YearMonth
# 3   Income   2020-01
# 7   Income   2020-01
# ...

# %%
monthly_income = income_df.groupby('YearMonth')['Amount'].sum()
monthly_income.head()
# Out:
# YearMonth
# 2020-01     6655.09
# 2020-02    20364.31
# 2020-03     3465.00
# 2020-04     9592.60
# 2020-05     6326.05
# Freq: M, Name: Amount, dtype: float64

# %%
monthly_income.plot(figsize=(12, 5))
plt.title('Monthly Income Trend')
plt.xlabel('Month')
plt.ylabel('Expense')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
monthly_expense.plot(figsize=(12,5), label='Expense')
monthly_income.plot(label='Income')
plt.title("Monthly Income vs Expense")
plt.xlabel('Month')
plt.ylabel('Amount')
plt.legend()
plt.tight_layout()
plt.show()

# %%
expense_df.head()
# Out:
#         Date             Transaction Description      Category   Amount  \
# 0 2020-01-02                         Score each.  Food & Drink  1485.69
# 1 2020-01-02                 Quality throughout.     Utilities  1475.58
# 2 2020-01-04  Instead ahead despite measure ago.          Rent  1185.08
# 4 2020-01-13        Future choice whatever from.  Food & Drink  1126.88
# 5 2020-01-14      Benefit suggest page southern.      Shopping   448.68
#
#       Type YearMonth
# 0  Expense   2020-01
# 1  Expense   2020-01
# 2  Expense   2020-01
# 4  Expense   2020-01
# 5  Expense   2020-01

# %%
top_expense = expense_df.sort_values(by='Amount', ascending=False)

# %%
top_expense.head()
# Out:
#           Date           Transaction Description          Category   Amount  \
# 173 2020-08-22                       Down occur.      Food & Drink  1999.82
# 243 2020-11-12        Order his oil west school.      Food & Drink  1999.15
# 354 2021-03-19                   Across nothing.      Food & Drink  1997.19
# 586 2022-01-21  Enter example down anyone occur.  Health & Fitness  1996.26
# 287 2020-12-28                    Song risk bad.            Travel  1994.88
#
#         Type YearMonth
# 173  Expense   2020-08
# 243  Expense   2020-11
# 354  Expense   2021-03
# 586  Expense   2022-01
# 287  Expense   2020-12

# %%
top_income = income_df.sort_values(by='Amount',ascending=False)
top_income.head()
# Out:
#            Date                 Transaction Description    Category  Amount  \
# 1286 2024-04-10  Environmental outside bed institution.  Investment  4996.0
# 1016 2023-06-02               Window career case south.  Investment  4981.0
# 588  2022-01-22                        Best deal point.       Other  4975.0
# 335  2021-03-02                              Occur red.       Other  4960.0
# 1389 2024-08-25                 Including time reflect.       Other  4906.0
#
#         Type YearMonth
# 1286  Income   2024-04
# 1016  Income   2023-06
# 588   Income   2022-01
# 335   Income   2021-03
# 1389  Income   2024-08

# %%
top5_expense = expense_df.sort_values(by='Amount', ascending=False).head()

# %%
top5_expense.plot(kind='barh',x = 'Transaction Description', y = 'Amount', figsize=(8,5))
plt.title('Largest Expenses')
plt.xlabel('Amount')
plt.ylabel('Category')
plt.yticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
expense_df.head()
# Out:
#         Date             Transaction Description      Category   Amount  \
# 0 2020-01-02                         Score each.  Food & Drink  1485.69
# 1 2020-01-02                 Quality throughout.     Utilities  1475.58
# 2 2020-01-04  Instead ahead despite measure ago.          Rent  1185.08
# 4 2020-01-13        Future choice whatever from.  Food & Drink  1126.88
# 5 2020-01-14      Benefit suggest page southern.      Shopping   448.68
#
#       Type YearMonth
# 0  Expense   2020-01
# 1  Expense   2020-01
# 2  Expense   2020-01
# 4  Expense   2020-01
# 5  Expense   2020-01

# %%
sns.countplot(data=expense_df, x='Category')
plt.title('Number of Transactions by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='Category', y='Amount', data=expense_df)
plt.title('Highest spread of Expense by Category')
plt.xlabel('Category')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.histplot(expense_df['Amount'], bins=10, kde=True)
plt.title('Transaction Amount Distribution')
plt.show()

# %%
numeric_df = clean_df.select_dtypes(include='number')

correlation_matrix = numeric_df.corr()

plt.figure(figsize=(8, 6))

sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5)

plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
sns.violinplot(x='Category', y='Amount', data=expense_df)
# Out:
# <Axes: xlabel='Category', ylabel='Amount'>
